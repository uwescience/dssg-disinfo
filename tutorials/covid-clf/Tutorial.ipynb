# %%
import numpy as np
import pandas as pd

neg = pd.read_csv('~/Downloads/negative_articles.csv')
pos = pd.read_csv('~/Downloads/positive_articles.csv')

# %%
neg.head()
# Out:
#    article_pk  domain_pk          domain_name  \
# 0    42301915         14    independent.co.uk
# 1    24447761          8             cnbc.com
# 2    34129035         14    independent.co.uk
# 3     1397777          6          cbsnews.com
# 4    14548788       1594  businessinsider.com
#
#                                          article_url  label  \
# 0  https://www.independent.co.uk/news/uk/home-new...      0
# 1  https://www.cnbc.com/2020/03/28/coronavirus-li...      0
# 2  https://www.independent.co.uk//news/uk/home-ne...      0
# 3  https://www.cbsnews.com/news/cbs-this-morning-...      0
# 4               http://www.businessinsider.com/?IR=T      0
#
#                                     article_headline  \
# 0  East Kent maternity scandal: Inquiry begins af...
# 1  NY Gov balks at federal quarantine talk, CDC w...
# 2  Scammers carrying out sextortion cybercrimes d...
# 3           Listen to the "CBS This Morning" podcast
# ...
